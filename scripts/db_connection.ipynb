# %%
# Import Dependencies
import pandas as pd
import os
from sqlalchemy import create_engine
from config import db_password
import time

# %%
# Files to Load
artist_to_load = "source_data/artist.csv"
artist_data_to_load = "source_data/artist_data.csv"
genre_data_to_load = "source_data/genre_data.csv"
year_data_to_load = "source_data/year_data.csv"
overall_data_to_load = "source_data/overall_data.csv"
track_data_to_load = "source_data/track_data.csv"

artist_data_df = pd.read_csv(artist_data_to_load, index_col=0)
genre_data_df = pd.read_csv(genre_data_to_load, index_col=0)
year_data_df = pd.read_csv(year_data_to_load, index_col=0)

# %%
# Connection String
db_string = f'postgres://nbumduguqxvlys:{db_password}@ec2-54-243-92-68.compute-1.amazonaws.com:5432/ddha93h7jehqkr'

# %%
# Create Engine
engine = create_engine(db_string)

# %%
# Import year_data DF into Database
year_data_df.to_sql(name='year_data', con=engine, if_exists='append')

# %%
# Import genre_data DF into Database
genre_data_df.to_sql(name='genre_data', con=engine, if_exists='append')

# %%
# create a variable for the number of rows imported
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(artist_to_load, chunksize=1000, index_col=0):

    # print out the range of rows that are being imported
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    
    remove_char = ["'", '[', ']']
    for char in remove_char:
        data['genres'] = data['genres'].str.replace(char, '')
    
    data.to_sql(name='artist', con=engine, if_exists='append', method='multi')

    # increment the number of rows imported by the size of 'data'
    rows_imported += len(data)
    
    # print that the rows have finished importing
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000...Done. 0.7628490924835205 total seconds elapsed
# importing rows 1000 to 2000...Done. 1.2836713790893555 total seconds elapsed
# importing rows 2000 to 3000...Done. 1.6443467140197754 total seconds elapsed
# importing rows 3000 to 4000...Done. 2.0741493701934814 total seconds elapsed
# importing rows 4000 to 5000...Done. 2.4742891788482666 total seconds elapsed
# importing rows 5000 to 6000...Done. 2.87467098236084 total seconds elapsed
# importing rows 6000 to 7000...Done. 3.344839334487915 total seconds elapsed
# importing rows 7000 to 8000...Done. 3.946255683898926 total seconds elapsed
# importing rows 8000 to 9000...Done. 4.326407194137573 total seconds elapsed
# importing rows 9000 to 10000...Done. 4.716393232345581 total seconds elapsed
# importing rows 10000 to 11000...Done. 5.177150011062622 total seconds elapsed
# importing rows 11000 to 12000...Done. 5.587555646896362 total seconds elapsed
# ...

# %%
# Import artist_data DF into Database
artist_data_df.to_sql(name='artist_data', con=engine, if_exists='append', method='multi')

# %%
# create a variable for the number of rows imported
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(overall_data_to_load, chunksize=1000, index_col=0):

    # print out the range of rows that are being imported
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    
    data.explicit = data.explicit.astype('bool')
    
    data.to_sql(name='overall_data', con=engine, if_exists='append', method='multi')

    # increment the number of rows imported by the size of 'data'
    rows_imported += len(data)
    
    # print that the rows have finished importing
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000...Done. 0.6740589141845703 total seconds elapsed
# importing rows 1000 to 2000...Done. 1.4260518550872803 total seconds elapsed
# importing rows 2000 to 3000...Done. 2.0160560607910156 total seconds elapsed
# importing rows 3000 to 4000...Done. 2.826540231704712 total seconds elapsed
# importing rows 4000 to 5000...Done. 3.57719349861145 total seconds elapsed
# importing rows 5000 to 6000...Done. 4.177602767944336 total seconds elapsed
# importing rows 6000 to 7000...Done. 4.978805780410767 total seconds elapsed
# importing rows 7000 to 8000...Done. 5.739802837371826 total seconds elapsed
# importing rows 8000 to 9000...Done. 6.359803676605225 total seconds elapsed
# importing rows 9000 to 10000...Done. 7.100804328918457 total seconds elapsed
# importing rows 10000 to 11000...Done. 7.6808021068573 total seconds elapsed
# importing rows 11000 to 12000...Done. 8.381802082061768 total seconds elapsed
# ...

# %%
# create a variable for the number of rows imported
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(track_data_to_load, chunksize=1000, index_col=0):

    # print out the range of rows that are being imported
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    
    data.explicit = data.explicit.astype('bool')
    
    # Dropping uncleaned artists column
    data = data.drop(columns=['artists.1'], axis=1)

    data.to_sql(name='track_data', con=engine, if_exists='append', method='multi')

    # increment the number of rows imported by the size of 'data'
    rows_imported += len(data)
    
    # print that the rows have finished importing
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000...Done. 0.8994879722595215 total seconds elapsed
# importing rows 1000 to 2000...Done. 1.6804819107055664 total seconds elapsed
# importing rows 2000 to 3000...Done. 2.560494899749756 total seconds elapsed
# importing rows 3000 to 4000...Done. 3.2717535495758057 total seconds elapsed
# importing rows 4000 to 5000...Done. 4.142350673675537 total seconds elapsed
# importing rows 5000 to 6000...Done. 5.023067235946655 total seconds elapsed
# importing rows 6000 to 7000...Done. 6.244546890258789 total seconds elapsed
# importing rows 7000 to 8000...Done. 7.2251200675964355 total seconds elapsed
# importing rows 8000 to 9000...Done. 8.176265478134155 total seconds elapsed
# importing rows 9000 to 10000...Done. 9.980265617370605 total seconds elapsed
# importing rows 10000 to 11000...Done. 11.099550247192383 total seconds elapsed
# importing rows 11000 to 12000...Done. 12.170437812805176 total seconds elapsed
# ...
